# %%
import pprint
import psycopg2
import sqlalchemy

# %%
sqlalchemy.create_engine('postgresql://team:petite-vacation-exceeding-tipoff-curry@a.enforge.de/pv')
# Out:
# Engine(postgresql://team:***@a.enforge.de/pv)

# %%
# %load_ext sql

# %%
# %sql postgresql://team:petite-vacation-exceeding-tipoff-curry@a.enforge.de/pv
# Out:
# 'Connected: team@pv'

# %%
# %%sql
# SELECT * FROM daily_yield limit 1000
# Out:
#  * postgresql://team:***@a.enforge.de/pv
# 1000 rows affected.
# [(4031, 'home2', datetime.date(2020, 7, 21), datetime.time(15, 15), Decimal('1660.00'), 'W'),
#  (4031, 'home2', datetime.date(2020, 7, 21), datetime.time(15, 20), Decimal('3290.00'), 'W'),
#  (4031, 'home2', datetime.date(2020, 7, 21), datetime.time(15, 25), Decimal('4250.00'), 'W'),
#  (4031, 'home2', datetime.date(2020, 7, 21), datetime.time(15, 30), Decimal('4210.00'), 'W'),
#  (4031, 'home2', datetime.date(2020, 7, 21), datetime.time(15, 35), Decimal('4080.00'), 'W'),
#  (4031, 'home2', datetime.date(2020, 7, 21), datetime.time(15, 40), Decimal('3990.00'), 'W'),
#  (4031, 'home2', datetime.date(2020, 7, 21), datetime.time(15, 45), Decimal('3910.00'), 'W'),
#  (4031, 'home2', datetime.date(2020, 7, 21), datetime.time(15, 50), Decimal('3810.00'), 'W'),
#  (4031, 'home2', datetime.date(2020, 7, 21), datetime.time(15, 55), Decimal('3720.00'), 'W'),
# ...

# %%
# !pip install pymysql

# %%
#%%sql 
import pandas 

result = %sql SELECT * FROM daily_yield limit 1000
df= pandas.DataFrame(result, columns=['solarlog_id','solarlog_subdomain','date','time','yield','unit'])
print(df)
type(df)
# Out:
#  * postgresql://team:***@a.enforge.de/pv
# 1000 rows affected.
#      solarlog_id solarlog_subdomain        date      time    yield unit
# 0           4031              home2  2020-07-21  15:15:00  1660.00    W
# 1           4031              home2  2020-07-21  15:20:00  3290.00    W
# 2           4031              home2  2020-07-21  15:25:00  4250.00    W
# 3           4031              home2  2020-07-21  15:30:00  4210.00    W
# 4           4031              home2  2020-07-21  15:35:00  4080.00    W
# ..           ...                ...         ...       ...      ...  ...
# 995         4031              home2  2020-07-19  21:30:00     0.00    W
# 996         4031              home2  2020-07-19  21:35:00     0.00    W
# 997         4031              home2  2020-07-19  21:40:00     0.00    W
# 998         4031              home2  2020-07-19  21:45:00     0.00    W
# 999         4031              home2  2020-07-19  21:50:00     0.00    W
#
# [1000 rows x 6 columns]
# ...

# %%
df1=df.drop(columns=['solarlog_id','solarlog_subdomain','unit','time'])
print(df1)
# Out:
#            date    yield
# 0    2020-07-21  1660.00
# 1    2020-07-21  3290.00
# 2    2020-07-21  4250.00
# 3    2020-07-21  4210.00
# 4    2020-07-21  4080.00
# ..          ...      ...
# 995  2020-07-19     0.00
# 996  2020-07-19     0.00
# 997  2020-07-19     0.00
# 998  2020-07-19     0.00
# 999  2020-07-19     0.00
#
# [1000 rows x 2 columns]

# %%
df1= df1.set_index('date')
print(df1)
# Out:
#               yield
# date
# 2020-07-21  1660.00
# 2020-07-21  3290.00
# 2020-07-21  4250.00
# 2020-07-21  4210.00
# 2020-07-21  4080.00
# ...             ...
# 2020-07-19     0.00
# 2020-07-19     0.00
# 2020-07-19     0.00
# 2020-07-19     0.00
# 2020-07-19     0.00
#
# [1000 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
df1['yield'].hist()
plt.show()

# %%
df1.head()
# Out:
#               yield
# date
# 2020-07-21  1660.00
# 2020-07-21  3290.00
# 2020-07-21  4250.00
# 2020-07-21  4210.00
# 2020-07-21  4080.00

# %%
df1.tail()
# Out:
#            yield
# date
# 2020-07-19  0.00
# 2020-07-19  0.00
# 2020-07-19  0.00
# 2020-07-19  0.00
# 2020-07-19  0.00

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
plot_acf(df1)
plot_pacf(df1)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from statsmodels.tsa.arima_model import ARMA,ARIMA, ARMAResults, ARIMAResults

# %%
from pmdarima import auto_arima # for determining ARIMA orders

# %%
auto_arima(df1['yield'],seasonal=False).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                 1000
# Model:               SARIMAX(2, 1, 2)   Log Likelihood               -8216.608
# Date:                Tue, 08 Dec 2020   AIC                          16443.217
# Time:                        21:39:59   BIC                          16467.751
# Sample:                             0   HQIC                         16452.542
#                                - 1000
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4646      0.056     -8.295      0.000      -0.574      -0.355
# ar.L2          0.4545      0.048      9.512      0.000       0.361       0.548
# ma.L1         -0.0861      0.054     -1.606      0.108      -0.191       0.019
# ...

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX
model = SARIMAX(df1['yield'].values,order=(0,0,1))
model_fit= model.fit()
rmse = sqrt(mean_squared_error(df['yield'].values,model_fit.fittedvalues)) 
print('Test RMSE: %.3f' % rmse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-8e79cf624c64> in <module>
#       1 from sklearn.metrics import mean_squared_error
#       2 from statsmodels.tsa.statespace.sarimax import SARIMAX
# ----> 3 model = SARIMAX(df1['yield'],order=(0,0,1))
#       4 model_fit= model.fit()
#       5 rmse = sqrt(mean_squared_error(df1['yield'],model_fit.fittedvalues))
#
# ~\anaconda3\envs\tf\lib\site-packages\statsmodels\tsa\statespace\sarimax.py in __init__(self, endog, exog, order, seasonal_order, trend, measurement_error, time_varying_regression, mle_regression, simple_differencing, enforce_stationarity, enforce_invertibility, hamilton_representation, concentrate_scale, trend_offset, use_exact_diffuse, dates, freq, missing, validate_specification, **kwargs)
#     330             trend=trend, enforce_stationarity=None, enforce_invertibility=None,
# ...
